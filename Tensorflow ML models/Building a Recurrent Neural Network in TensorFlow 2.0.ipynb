# %% [markdown]
# ## Stage 1: Install dependencies and setting up GPU environment

# %%
# !pip install numpy==1.16.1
# Out:
# Requirement already satisfied: numpy==1.16.1 in /usr/local/lib/python3.7/dist-packages (1.16.1)

# %% [markdown]
# ## Stage 2: Importing project dependencies

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.datasets import imdb

# %%
tf.__version__
# Out:
# '2.7.0'

# %% [markdown]
# ## Stage 3: Dataset preprocessing

# %% [markdown]
# ### Setting up dataset parameters

# %%
number_of_words = 30000
max_len = 100

# %% [markdown]
# ### Loading the IMDB dataset

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=number_of_words)

# %% [markdown]
# ### Padding all sequences to be the same length

# %%
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, maxlen=max_len)

# %%
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, maxlen=max_len)

# %% [markdown]
# ### Setting up Embedding Layer parameters

# %%
vocab_size = number_of_words
vocab_size
# Out:
# 30000

# %%
embed_size = 128

# %% [markdown]
# ## Step 4: Building a Recurrent Neural Network

# %% [markdown]
# ### Defining the model

# %%
model = tf.keras.Sequential()

# %% [markdown]
# ### Adding the Embeding Layer

# %%
model.add(tf.keras.layers.Embedding(vocab_size, embed_size, input_shape=(X_train.shape[1],)))

# %% [markdown]
# ### Adding the LSTM Layer
#
# - units: 128
# - activation: tanh

# %%
model.add(tf.keras.layers.LSTM(units=128, activation='tanh'))

# %% [markdown]
# ### Adding the Dense output layer
#
# - units: 1
# - activation: sigmoid

# %%
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### Compiling the model

# %%
opt = tf.keras.optimizers.RMSprop(learning_rate = 10**-3)

# %%
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 128)          3840000
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,971,713
# Trainable params: 3,971,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train, y_train, epochs=3, batch_size=128)
# Out:
# Epoch 1/3
# 196/196 [==============================] - 8s 27ms/step - loss: 0.4493 - accuracy: 0.7902
# Epoch 2/3
# 196/196 [==============================] - 5s 27ms/step - loss: 0.2785 - accuracy: 0.8884
# Epoch 3/3
# 196/196 [==============================] - 5s 27ms/step - loss: 0.2180 - accuracy: 0.9169

# %% [markdown]
# ### Evaluating the model

# %%
test_loss, test_acurracy = model.evaluate(X_test, y_test)
# Out:
# 782/782 [==============================] - 9s 10ms/step - loss: 0.4397 - accuracy: 0.8408

# %%
print("Test accuracy: {}".format(test_acurracy))
# Out:
# Test accuracy: 0.8407599925994873
